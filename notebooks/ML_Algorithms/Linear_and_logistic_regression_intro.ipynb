# %% [markdown]
# # Linear and Logistic Regression Intro
#
# **Author:** Tohidul Islam Tareq
#
# A simple visual introduction to linear regression and logistic regression.

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)
plt.rcParams['figure.figsize'] = (7, 4)

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression

rng = np.random.default_rng(RANDOM_STATE)
X = rng.normal(0, 1, 120).reshape(-1, 1)
y_reg = 2.5*X.ravel() + 4 + rng.normal(0, 0.8, 120)
y_cls = (y_reg > np.median(y_reg)).astype(int)

lin = LinearRegression().fit(X, y_reg)
log = LogisticRegression().fit(X, y_cls)

grid = np.linspace(X.min(), X.max(), 200).reshape(-1, 1)
plt.figure()
plt.scatter(X, y_reg, alpha=0.6)
plt.plot(grid, lin.predict(grid), label='linear fit')
plt.legend(); plt.grid(True); plt.show()

plt.figure()
plt.scatter(X, y_cls, alpha=0.6)
plt.plot(grid, log.predict_proba(grid)[:,1], label='logistic probability')
plt.legend(); plt.grid(True); plt.show()
