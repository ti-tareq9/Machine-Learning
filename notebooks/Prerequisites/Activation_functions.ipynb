# %% [markdown]
# # Activation Functions
#
# **Author:** Tohidul Islam Tareq
#
# Common activation functions used in machine learning and neural networks.

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)
plt.rcParams['figure.figsize'] = (7, 4)

# %%
def step(z): return (z >= 0).astype(int)
def sigmoid(z): return 1 / (1 + np.exp(-z))
def tanh(z): return np.tanh(z)
def relu(z): return np.maximum(0, z)
def leaky_relu(z, alpha=0.1): return np.where(z > 0, z, alpha*z)

z = np.linspace(-6, 6, 400)
functions = {'Step': step(z), 'Sigmoid': sigmoid(z), 'Tanh': tanh(z), 'ReLU': relu(z), 'Leaky ReLU': leaky_relu(z)}
for name, values in functions.items():
    plt.figure()
    plt.plot(z, values)
    plt.title(name)
    plt.xlabel('z'); plt.ylabel('f(z)')
    plt.grid(True)
    plt.show()

# %%
summary = pd.DataFrame({
    'activation': ['Step', 'Sigmoid', 'Tanh', 'ReLU', 'Leaky ReLU'],
    'typical_use': ['classic perceptron', 'binary output', 'hidden layers', 'deep networks', 'deep networks'],
    'output_range': ['{0, 1}', '(0, 1)', '(-1, 1)', '[0, infinity)', '(-infinity, infinity)']
})
summary
# Out:
#    activation         typical_use           output_range
# 0        Step  classic perceptron                 {0, 1}
# 1     Sigmoid       binary output                 (0, 1)
# 2        Tanh       hidden layers                (-1, 1)
# 3        ReLU       deep networks          [0, infinity)
# 4  Leaky ReLU       deep networks  (-infinity, infinity)
