# %% [markdown]
# # Loss Functions
#
# **Author:** Tohidul Islam Tareq
#
# Visualization and comparison of common regression and classification losses.

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)
plt.rcParams['figure.figsize'] = (7, 4)

# %%
error = np.linspace(-3, 3, 400)
losses = {
    'Squared loss': error**2,
    'Absolute loss': np.abs(error),
    'Huber loss': np.where(np.abs(error) <= 1, 0.5*error**2, np.abs(error)-0.5)
}
for name, loss in losses.items():
    plt.figure()
    plt.plot(error, loss)
    plt.title(name)
    plt.xlabel('prediction error'); plt.ylabel('loss')
    plt.grid(True)
    plt.show()

# %%
y_true = np.array([1, 0, 1, 1, 0])
y_prob = np.array([0.90, 0.20, 0.75, 0.60, 0.10])
eps = 1e-15
binary_cross_entropy = -np.mean(y_true*np.log(y_prob+eps) + (1-y_true)*np.log(1-y_prob+eps))
print(f'Binary cross-entropy: {binary_cross_entropy:.4f}')
# Out:
# Binary cross-entropy: 0.2465
